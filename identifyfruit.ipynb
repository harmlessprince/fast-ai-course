# %% [markdown]
# <a href="https://colab.research.google.com/github/harmlessprince/fast-ai-course/blob/main/identifyfruit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 # !pip install -Uqq fastai ddgs
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.5/42.5 kB 1.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 35.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 43.7 MB/s eta 0:00:00

# %%
from fastai.vision.all import *
from ddgs import DDGS

# %%
def search_images(term, max_images=50):
    with DDGS() as ddgs:
        return [r["image"] for r in ddgs.images(term, max_results=max_images)]

# %%
apple_images = search_images("apple fruit", max_images=50)
orange_images = search_images("orange fruit", max_images=50)
banana_images = search_images("banana fruit", max_images=50)
apple_images[0]
# Out:
# 'https://healthjade.com/wp-content/uploads/2017/10/apple-fruit.jpg'

# %%
from fastdownload import download_url

path = Path('fruits')
path.mkdir(exist_ok=True)

for label, images in [("apple", apple_images), ("orange", orange_images), ("banana", banana_images)]:
    dest = path/label
    dest.mkdir(exist_ok=True)
    for url in images:
        try:
            download_url(url, dest/Path(url).name, show_progress=False)
        except Exception as e:
            print(f"Failed to download {url}: {e}")
# Out:
# Failed to download https://get.pxhere.com/photo/plant-fruit-orange-food-produce-juicy-juice-fruits-tangerine-calabaza-clementine-vegetarian-food-vitamins-oranges-sliced-citrus-flowering-plant-citrus-fruit-bitter-orange-mandarin-orange-land-plant-sweet-lemon-tangelo-valencia-orange-navel-oranges-bahia-orange-citrus-sinensis-1343906.jpg: [Errno 36] File name too long: 'fruits/orange/plant-fruit-orange-food-produce-juicy-juice-fruits-tangerine-calabaza-clementine-vegetarian-food-vitamins-oranges-sliced-citrus-flowering-plant-citrus-fruit-bitter-orange-mandarin-orange-land-plant-sweet-lemon-tangelo-valencia-orange-navel-oranges-bahia-orange-citrus-sinensis-1343906.jpg'
# Failed to download https://www.quanta.org/orange/orange.jpg: <urlopen error [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1010)>
# Failed to download https://rare-gallery.com/uploads/posts/784001-Orange-fruit-Fruit-Two-Orange.jpg: HTTP Error 403: Forbidden
# ====Error Body====
# <!DOCTYPE html><html lang="en-US"><head><title>Just a moment...</title><meta http-equiv="Content-Type" content="text/html; charset=UTF-8"><meta http-equiv="X-UA-Compatible" content="IE=Edge"><meta name="robots" content="noindex,nofollow"><meta name="viewport" content="width=device-width,initial-scale=1"><style>*{box-sizing:border-box;margin:0;padding:0}html{line-height:1.15;-webkit-text-size-adjust:100%;color:#313131;font-family:system-ui,-apple-system,BlinkMacSystemFont,"Segoe UI",Roboto,"Helvetica Neue",Arial,"Noto Sans",sans-serif,"Apple Color Emoji","Segoe UI Emoji","Segoe UI Symbol","Noto Color Emoji"}body{display:flex;flex-direction:column;height:100vh;min-height:100vh}.main-content{margin:8rem auto;padding-left:1.5rem;max-width:60rem}@media (width <= 720px){.main-content{margin-top:4rem}}.h2{line-height:2.25rem;font-size:1.5rem;font-weight:500}@media (width <= 720px){.h2{line-height:1.5rem;font-size:1.25rem}}#challenge-error-text{background-image:url("data:image/svg+xml;base64,...");background-repeat:no-repeat;background-size:contain;padding-left:34px}@media (prefers-color-scheme: dark){body{background-color:#222;color:#d9d9d9}}</style><meta http-equiv="refresh" content="360"></head><body><div class="main-wrapper" role="main"><div class="main-content"><noscript><div class="h2"><span id="challenge-error-text">Enable JavaScript and cookies to continue</span></div></noscript></div></div><script>
qIdOdIYCfVyaMtgUJKaxolTD6w85QQ',mdrd: 'JzB0z.dZRsGKDQCFSf9MP2PJqvDjbXxATD.hiGTEWWo-1762670334-1.2.1.1-N_GqyScnJkboMW.FqvKhx1iLReq_.A2PpOPUNIcuwtRxwGykzdq2HKCVitSvAoDQmn2mC4WVpgC3FZA6JNeYUnxy8anqJ3Gk_5INf1mKnkD652N06M61mwpCcaKNDbi.a_.8c9.kOFekc782uLCEmcb3hiU4afcbbxuoCIY2iCPvw5LIeqbsDaPrgiiixUPr9XALeRZMaeUv3g2zuhmQpFEsPfPR7siaJtk030rYNIytldbDOj5oxmXlFqwHG2DVEoVNwUZuBD6a8iSOVktaPHV3CHLu5viAPZ8rapq6i0n9GxdJ31XBeN3Ec.JHPqekBO1YPURcnxd2PHmb9Va.eZ9GAjiRHsftSw4vRE3XuYOXxdgVsteJeMNe_rHNpKHyDC3SNWibXYSjxI8hM.fEkXL7fXDVIff.eDKmcERQFD2kZLjJ1Y_DJyLHjr..TzNU8xPF8e4l.qrb.NXiAKiFz9H_QiUqjzhRJ_PV1H7Jc.lg9beEbSF5hZ5WruSKJlfrquu0AjuhGcQyDcd9JI.GesHhpYavyGYMbUpxqxJ3y2CaSh46yovnCxOKwWS2G8yuSXyWyqiOpH2evTU9ODEjb8vulsoblRGKd0AxZ50Ypnv2rqyTL6ayjCa.SeuGSTi8KYHrBEY_k ...
# </body></html>
# Failed to download https://i0.wp.com/www.theayurveda.org/wp-content/uploads/2015/11/banana-fruit-for-health.jpg?fit=2048,1152&ssl=1: HTTP Error 404: Not Found
# ====Error Body====
# <html>
# <head><title>404 Not Found</title></head>
# <body>
# <center><h1>404 Not Found</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
# <!-- a padding to disable MSIE and Chrome friendly error page -->
# <!-- a padding to disable MSIE and Chrome friendly error page -->
# <!-- a padding to disable MSIE and Chrome friendly error page -->
# <!-- a padding to disable MSIE and Chrome friendly error page -->
# <!-- a padding to disable MSIE and Chrome friendly error page -->
# <!-- a padding to disable MSIE and Chrome friendly error page -->
#
# Failed to download https://wallpapercrafter.com/desktop/294644-bananas-fruits-fruit-healthy-yellow-banana-peel.jpg: HTTP Error 403: Forbidden
# ====Error Body====
# <!DOCTYPE html><html lang="en-US"><head><title>Just a moment...</title><meta http-equiv="Content-Type" content="text/html; charset=UTF-8"><meta http-equiv="X-UA-Compatible" content="IE=Edge"><meta name="robots" content="noindex,nofollow"><meta name="viewport" content="width=device-width,initial-scale=1"><style>*{box-sizing:border-box;margin:0;padding:0}html{line-height:1.15;-webkit-text-size-adjust:100%;color:#313131;font-family:system-ui,-apple-system,BlinkMacSystemFont,"Segoe UI",Roboto,"Helvetica Neue",Arial,"Noto Sans",sans-serif,"Apple Color Emoji","Segoe UI Emoji","Segoe UI Symbol","Noto Color Emoji"}body{display:flex;flex-direction:column;height:100vh;min-height:100vh}.main-content{margin:8rem auto;padding-left:1.5rem;max-width:60rem}@media (width <= 720px){.main-content{margin-top:4rem}}.h2{line-height:2.25rem;font-size:1.5rem;font-weight:500}@media (width <= 720px){.h2{line-height:1.5rem;font-size:1.25rem}}#challenge-error-text{background-image
ST4UMZwfynsbZvx37sxopYTfQ1jHSlUmGKG8n.sTuCFUd4SVhC_C1Rh2v4UKEa.oAutMHlpjQDuieKLoo4FD1BNFT6sAav9MaB.gC1nJRKAYm8.eUx9.OH9bRgYdyolOOoYfKH._PIw0aaY9fKn25AT_m4URhmbLDFwasKRZKSRgRH4CnT.72XEGQi43v90wqniH9QT0FVX6QQmjdhCOP0KpzvdQdw8xOPa9UisJLsRIO4EIjx0GfiudI',mdrd: 'C_ZFeGINpuxSoPcMAqOqF.Qo6MAlHnSTgLmZm0gheCo-1762670356-1.2.1.1-iJbiNTkiCxN8V6lUixdqeaEQ4u0Z.X1F62An_9nC9ZQb3rOZe4cR5TyWjA7q5y8C9wTFBhLQR9VvLPTaw_U8ptRXt02YQNBhkDz1kSN4gpcPmpSAgiwA_4lnPVpxJdCxQcMVZaGGDFDDQiPyT1hQQwhBUnbFey71z9PqhZcqRECdMYnoybKKNG6aIpaUJSnd7gcFIde0FZ18E759yBf5zpI5KUb7TV8lLbVp_jlD3HErtjmBDvP4R.RJvwA6nwFIObGpnxOaMtXbby17eatw2eub08XOLRyFct16uw.Qf5tAP9SwQ0chGz46EnAKgkLN9rwiQTrqaEvXZYXxnzuzbrbirSXrwBHCRXda918z.ajHZD7LBVJocvla8PXpdwj0S9ZJHwxo2xbFIHQ2ypjE8NSoYvtyXCCoiEv_FiFgAwglAL6Ow5n5vOBjPyO_HxW3VYpAyuRvTViCOOgAj.HDelrq3.qXe6IaEpWoE4OQMP_PhJLzqyioDPUaqM1dLmMGz5L6QQapSjiYm3KO8PNyhPAZvn8tKZQoqT.5j8mJjYkf_PgaedNJcRp0nvehk91ccIAUizdsujGdSc5ryr43qYQqIu ...
# </body></html>

# %%
failed = verify_images(get_image_files(path))
failed.map(Path.unlink)
len(failed)
# Out:
# 0

# %%
dls = DataBlock(
    blocks=(ImageBlock, CategoryBlock),
    get_items=get_image_files,
    splitter=RandomSplitter(valid_pct=0.2, seed=42),
    get_y=parent_label,
    item_tfms=[Resize(192, method='squish')]
).dataloaders(path, bs=32)

dls.show_batch(max_n=6)
# Out:
# /usr/local/lib/python3.12/dist-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(

# %%
learn = vision_learner(dls, resnet18, metrics=error_rate)
learn.fine_tune(3)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.751279</td>
#       <td>0.812427</td>
#       <td>0.333333</td>
#       <td>00:08</td>
#     </tr>
#   </tbody>
# </table>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.614369</td>
#       <td>0.160191</td>
#       <td>0.000000</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.375801</td>
#       <td>0.055380</td>
#       <td>0.000000</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.256216</td>
#       <td>0.052704</td>
#       <td>0.000000</td>
#       <td>00:08</td>
#     </tr>
#   </tbody>
# </table>

# %%
# img = PILImage.create('')
url = "https://5.imimg.com/data5/PM/PO/FI/SELLER-47385627/fresh-high-quality-green-banana-1000x1000.jpg"
img = Image.open(requests.get(url, stream=True).raw).convert('RGB')
img.save("temp.jpg")
img = PILImage.create("temp.jpg")
pred_class, pred_idx, probs = learn.predict(img)
print(f"Prediction: {pred_class}; Probability: {probs[pred_idx]:.4f}")
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# Prediction: banana; Probability: 0.9997

# %%
img = PILImage.create(requests.get(url, stream=True).raw)
img.show()
# Out:
# <Axes: >
